# %% [markdown]
# # Import Exercises
# You will need to use imports to complete each exercise; in addition, these exercise will strengthen your problem solving and python coding skills.
#
# You will be directed to create specific files in part 1, for the rest you may do your work in either `import_exercises.py` or `import_exercises.ipynb`.

# %% [markdown]
# <hr style="border:2px solid gray">

# %% [markdown]
# # Exercise # 1
# ### Import and test 3 of the functions from your `functions exercise file`. Import each function in a different way:

# %% [markdown]
# ### <div class="alert alert-warning" role="alert">Make sure your code that tests the function imports, is run from the same directory that your functions exercise file is in.
# </div>

# %% [markdown]
# ## a) Run an interactive python session **IN TERMINAL** and import the module.
# >#### Call the `is_vowel` function using the `.` syntax.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# > In terminal:
# >
# > `cd ` to the correct directory
# >
# > `python`
# >
# >  `import functions as f`
# >
# >  `f.is_vowel('e')`
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - `quit()` or **[Ctrl][D]** to exit the python env

# %% [markdown]
# ## b)  Create a file named `import_exercises.py`.
# > #### Within this file, use `from` to import the `calculate_tip` function directly.
# > #### Call this function with values you choose and print the result.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# > In terminal:
# >
# > `touch import_exercises.py`
# >
# > `open import_exercises.py`
#
# OR
# > `code import_exercises.py`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# > In VS Code/code editor:
# >
# >`# IMPORTS`
# >
# >`from function_exercises import calculate_tip`
# >
# >`# MAIN SCRIPT`
# >
# >`bill = float(input("How much is the bill? : "))`
# >
# >`tip = float(input("What is the decimal tip you'd like to leave? (15% = 0.15) :  "))`
# >
# >`#print(calculate_tip(bill, tip))`
# >
# >`print(f"Your bill's tip is: ${round(calculate_tip(bill, tip), 2)}")`
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# > In terminal:
# >
# > `python import_exercises.py`
# </div>

# %% [markdown]
# ## c) Create a jupyter notebook named `import_exercises.ipynb`.
# >#### Use from to import the `get_letter_grade` function and give it an ***alias***.
# >#### Test this function in your notebook.

# %%
#import
from functions import get_letter_grade as glg

# %%
glg(76)
# Out:
# 'C'

# %%
glg(92)
# Out:
# 'A'

# %%
glg(64)
# Out:
# 'F'

# %% [markdown]
# <hr style="border:2px solid black">

# %% [markdown]
# # Exercise # 2
# ### Read about and use the <a href='https://docs.python.org/3/library/itertools.html'>`itertools` module</a> from the python standard library to help you solve the following problems

# %% [markdown]
# ##### <div class="alert alert-warning" role="alert">(Hint: wrap the itertools results in a list to see the results).</div>

# %%
#import
import itertools as it

# %% [markdown]
# ## a) How many different ways can you combine a single letter from "abc" with either 1, 2, or 3?
# > - This can be visualized as a <a href ='https://www.sqlshack.com/wp-content/uploads/2020/02/sql-cross-join-working-mechanism.png'>SQL Cross Join</a> or a <a href = 'https://miro.medium.com/v2/resize:fit:1400/1*ofgbRmZT2avae5mqvU6c2Q.jpeg'>Cartesian Product</a>

# %%
#what happens if we just use itertools?
#we will get information but not the answer we want

combo = itertools.product("abc",[1,2,3])
print(combo)

# %%
# returns an object of type `itertools.product`. 
#itertools.product is an **iterator**, so the contents is not output by print()

type(combo)
# Out:
# itertools.product

# %%
#Option 1
#Convert the itertools.product -> list

list(it.product("abc",[1,2,3]))
# Out:
# [('a', 1),
#  ('a', 2),
#  ('a', 3),
#  ('b', 1),
#  ('b', 2),
#  ('b', 3),
#  ('c', 1),
#  ('c', 2),
#  ('c', 3)]

# %%
#Option 2
#Return the length of the list

combo = it.product("abc",[1,2,3])
print(f"'abc' and 123 can be combined in {len(list(combo))} different ways.")
# Out:
# 'abc' and 123 can be combined in 9 different ways.

# %%
#Option 3
#Unpack the product using List comprehension:

clist = [c for c in itertools.product("abc",[1,2,3])]
print(clist)
# Out:
# [('a', 1), ('a', 2), ('a', 3), ('b', 1), ('b', 2), ('b', 3), ('c', 1), ('c', 2), ('c', 3)]

# %%
# or using a `for` loop

for c in itertools.product("abc",[1,2,3]):
    print(c)
# Out:
# ('a', 1)
# ('a', 2)
# ('a', 3)
# ('b', 1)
# ('b', 2)
# ('b', 3)
# ('c', 1)
# ('c', 2)
# ('c', 3)

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## b) How many different <u>combinations</u> are there of 2 letters from "abcd"?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>NOTE:</b>
# Combinations vs Permutations:
# <br>
#
# - Combinations- non-repeating combinations
# - Permutations- every combination in every order
#
# #### 1. Permutation: ***Order matters***. How may possible arrangements can the iterable/input be placed in?
# - Think of a **p**assword: `1234` is not the same password as `4321`
# >
#
# #### 2. Combination: Order ***Doesn't*** matter, **uniqueness matters**.
# - Think of **c**oworkers: `Madeleine and Tasha` is the same as `Tasha and Madeleine`
#     </div>

# %% [markdown]
# ![combos_vs_perms.png](attachment:combos_vs_perms.png)

# %%
#show the list
list(it.combinations("abcd", 2))
# Out:
# [('a', 'b'), ('a', 'c'), ('a', 'd'), ('b', 'c'), ('b', 'd'), ('c', 'd')]

# %%
#count how many combos are in that list
len(list(it.combinations("abcd", 2)))
# Out:
# 6

# %%
#put it into a nice print statement
print(f'''There are {len(list(itertools.combinations("abcd", 2)))} two-letter combinations of 'abcd'. ''')
# Out:
# There are 6 two-letter combinations of 'abcd'.

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## c) How many different permutations are there of 2 letters from "abcd"?

# %%
#This produces a list of possible 2-letter permutations for 'abcd'

list(itertools.permutations("abcd", 2))
# Out:
# [('a', 'b'),
#  ('a', 'c'),
#  ('a', 'd'),
#  ('b', 'a'),
#  ('b', 'c'),
#  ('b', 'd'),
#  ('c', 'a'),
#  ('c', 'b'),
#  ('c', 'd'),
#  ('d', 'a'),
#  ('d', 'b'),
#  ('d', 'c')]

# %%
# Output the NUMBER of permutations

len(list(itertools.permutations("abcd", 2)))
# Out:
# 12

# %% [markdown]
# <hr style="border:2px solid black">

# %% [markdown]
# # Exercise # 3
# ### Save <a href='https://gist.githubusercontent.com/misty-garcia/bf100f7418eb26446507166b4f50a18a/raw/a48b7071dabf32991ff5de3c91b633ecd1a95e42/profiles.json'>this</a> file as `profiles.json` inside of your exercises directory.
# (right click -> save file as...)
#
# Use the `load` function from the `json` module to open this file.

# %%
#import
import json

#Save json file for reference

profiles = json.load(open('profiles.json'))

# %% [markdown]
# Your code should produce a list of dictionaries. Using this data, write some code that calculates and outputs the following information:

# %%
#[]:list
#{}: dict
#our JSON file is a list of dictionaries

profiles
# Out:
# [{'_id': '54e23c3e46ab53a440b580e8',
#   'index': 0,
#   'guid': '9962b468-ef3e-4993-b677-617469bc3008',
#   'isActive': False,
#   'balance': '$2,097.02',
#   'picture': 'http://placehold.it/32x32',
#   'age': 39,
#   'eyeColor': 'blue',
#   'name': 'Hebert Estes',
#   'gender': 'male',
#   'company': 'ANDRYX',
#   'email': 'hebertestes@andryx.com',
#   'phone': '+1 (866) 456-2268',
#   'address': '121 Emmons Avenue, Klondike, Kentucky, 5975',
#   'about': 'Sit cillum deserunt irure laboris tempor fugiat laboris. Amet commodo amet est incididunt. Dolore qui fugiat cillum pariatur dolore excepteur elit ipsum.\r\n',
#   'registered': '2014-11-10T01:44:03 +06:00',
#   'latitude': -80.157843,
#   'longitude': 161.93016,
#   'tags': ['sit', 'occaecat', 'non', 'ea', 'sit', 'laboris', 'exercitation'],
#   'friends': [{'id': 0, 'name': 'Tanisha Leonard'},
#    {'id': 1, 'name': 'Dennis Wilson'},
#    {'id': 2, 'name': 'Lupe Howe'}],
# ...

# %% [markdown]
# #### After doing a quick review of the questions, I notice there are a few aggregations I will be asked to perform.
#
# To minimize potential hiccups, let's explore the data a bit further, especially the `datatypes`.

# %%
# Use list indexing to observe the first dictionary in the file:

profiles[0]
# Out:
# {'_id': '54e23c3e46ab53a440b580e8',
#  'index': 0,
#  'guid': '9962b468-ef3e-4993-b677-617469bc3008',
#  'isActive': False,
#  'balance': '$2,097.02',
#  'picture': 'http://placehold.it/32x32',
#  'age': 39,
#  'eyeColor': 'blue',
#  'name': 'Hebert Estes',
#  'gender': 'male',
#  'company': 'ANDRYX',
#  'email': 'hebertestes@andryx.com',
#  'phone': '+1 (866) 456-2268',
#  'address': '121 Emmons Avenue, Klondike, Kentucky, 5975',
#  'about': 'Sit cillum deserunt irure laboris tempor fugiat laboris. Amet commodo amet est incididunt. Dolore qui fugiat cillum pariatur dolore excepteur elit ipsum.\r\n',
#  'registered': '2014-11-10T01:44:03 +06:00',
#  'latitude': -80.157843,
#  'longitude': 161.93016,
#  'tags': ['sit', 'occaecat', 'non', 'ea', 'sit', 'laboris', 'exercitation'],
#  'friends': [{'id': 0, 'name': 'Tanisha Leonard'},
#   {'id': 1, 'name': 'Dennis Wilson'},
#   {'id': 2, 'name': 'Lupe Howe'}],
#  'greeting': 'Hello, Hebert Estes! You have 4 unread messages.',
# ...

# %%
# Access a particular dictionary element using its key

profiles[0]['index']
# Out:
# 0

# %%
#Check the datatype
type(profiles[0]['index'])
# Out:
# int

# %%
#Check the datatype
type(profiles[0]['isActive'])
# Out:
# bool

# %%
#Check the datatype- this might need to be corrected
type(profiles[0]['balance'])
# Out:
# str

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>NOTE:</b>
#
# Because our balance is currently a string datatype, we will need to <i>clean</i> it.
#
# Removing special characters and converting the datatype will fix this.
#     </div>

# %%
#create a function that makes the desired corrections
#remove $, remove commas, and make a float
def clean_balance(balance):
    '''
    This function will:
        - remove $ and ,
        - convert str to float
    '''
    balance = balance.replace("$", "")
    balance = balance.replace(",", "")
    return float(balance)

# %%
#check to make sure our function works
clean = clean_balance("$10,213.42")
clean
# Out:
# 10213.42

# %%
#double check that balance was changed from str to float
#its a float and not int because there are decimal points
type(clean)
# Out:
# float

# %%
#use our new function on our ENTIRE DATASET
#for each profile in the profiles
#clean "balance"
for profile in profiles:
    profile['balance'] = clean_balance(profile['balance'])

# %%
#check to make sure that our function worked on the entire dataset for balance
#here's an example of the 3rd element
type(profiles[2]['balance'])
# Out:
# float

# %%
#Let's import Pretty Print, it helps make JSON files much more readable.
import pprint

# %%
#And we'll add in a line break along with the reformatting to check ALL of the profiles

for profile in profiles:
    pprint.pprint(profile)
    print('------------------------', '\n')
# Out:
# {'_id': '54e23c3e46ab53a440b580e8',
#  'about': 'Sit cillum deserunt irure laboris tempor fugiat laboris. Amet '
#           'commodo amet est incididunt. Dolore qui fugiat cillum pariatur '
#           'dolore excepteur elit ipsum.\r\n',
#  'address': '121 Emmons Avenue, Klondike, Kentucky, 5975',
#  'age': 39,
#  'balance': 2097.02,
#  'company': 'ANDRYX',
#  'email': 'hebertestes@andryx.com',
#  'eyeColor': 'blue',
#  'favoriteFruit': 'strawberry',
#  'friends': [{'id': 0, 'name': 'Tanisha Leonard'},
#              {'id': 1, 'name': 'Dennis Wilson'},
#              {'id': 2, 'name': 'Lupe Howe'}],
#  'gender': 'male',
#  'greeting': 'Hello, Hebert Estes! You have 4 unread messages.',
#  'guid': '9962b468-ef3e-4993-b677-617469bc3008',
#  'index': 0,
#  'isActive': False,
#  'latitude': -80.157843,
#  'longitude': 161.93016,
#  'name': 'Hebert Estes',
#  'phone': '+1 (866) 456-2268',
#  'picture': 'http://placehold.it/32x32',
#  'registered': '2014-11-10T01:44:03 +06:00',
# ...

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3a. Total number of users

# %%
#Create a variable of all profile_id's in a list

profile_ids = [profile['_id'] for profile in profiles]

# %%
#Use `set()` funct to confirm there are no duplicates.
# Since set objects are unordered, non-duplicated items listed as a singular variable.
set(profile_ids)
# Out:
# {'54e23c3e09cc6875638cd36b',
#  '54e23c3e0fd8074c2ca52667',
#  '54e23c3e177caf5567ba87ac',
#  '54e23c3e4192cf53edd67c99',
#  '54e23c3e42676228c442a669',
#  '54e23c3e46ab53a440b580e8',
#  '54e23c3e4ac5969958013235',
#  '54e23c3e502a2f526b689c3e',
#  '54e23c3e54e4094147a3b1da',
#  '54e23c3e69d22e49c7fe62de',
#  '54e23c3e6d89c09f5507e7dd',
#  '54e23c3eaffbb506aa15ec1c',
#  '54e23c3eb112d96e4204914d',
#  '54e23c3eb813e66c6d33aa82',
#  '54e23c3ebd80e9c26b057fa3',
#  '54e23c3ed945981ba2580614',
#  '54e23c3eedcc65f0ec3a5496',
#  '54e23c3ef30f14d0e5afddf3',
#  '54e23c3ef5cc0d250968c212'}

# %%
type(set(profile_ids))
# Out:
# set

# %%
#set variable for total number of users
#count of how many profile_ids we have

total_num_users = len(set(profile_ids))

#call new variable
total_num_users
# Out:
# 19

# %%
#or the easy way
len(profiles)
# Out:
# 19

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3b. Number of active users

# %%
#name variable active_users
#for all the individual profiles in IF the profile "isActive"
active_users = [profile for profile in profiles if profile['isActive'] == True]

#get the length of those isActive users, which we named active_users
len(active_users)
# Out:
# 9

# %%
#ANOTHER way to accomplish the same thing
#start with 0 and add one for each time that isActive is equal to True
act_count = 0 

for profile in profiles:
    if profile['isActive'] == True:
        act_count += 1  
        
act_count
# Out:
# 9

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3c. Number of inactive users

# %%
#name variable active_users
#for all the individual profiles in IF the profile "isActive"
inactive_users = [profile for profile in profiles if profile['isActive'] == False]

#get the length of those isActive users, which we named active_users
len(inactive_users)
# Out:
# 10

# %%
#name variable inactive_users
#for all the individual profiles in IF the profile is NOT "isActivie"
inactive_users = [profile for profile in profiles if (not profile['isActive'])]

#get the length of those who are not isActive users, which we named inactive_users
len(inactive_users)
# Out:
# 10

# %%
#another way
count = 0

for profile in profiles:
    if profile['isActive'] == False:
        count += 1
        
print(count)
# Out:
# 10

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3d. Grand total of balances for all users

# %%
total_balance = 0

for profile in profiles:
    total_balance += profile['balance']
    
print(f"Grand Total Balance for All Users is: $ {total_balance}")
# Out:
# Grand Total Balance for All Users is: $ 52667.02

# %% [raw]
# #IF you had not already cleaned the balance- you would need to do that here
#
# grand_total = 0
#
# for profile in profiles:
#     user_balance = float(profile['balance'].strip('$').replace(',', ''))
#     grand_total = grand_total + user_balance
#
# print(grand_total)

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3e. Average balance per user

# %%
#name variable average_balance
#total balance from above divided by total number of users (which we already know is 19)
average_balance = total_balance/total_num_users

#call new variable
average_balance
# Out:
# 2771.9484210526316

# %%
#same answer
#use total balance from above and then just divide by 19, since we already know we have 19 users
total_balance/19
# Out:
# 2771.9484210526316

# %%
#clean it up by rounding to two decimal places
rounded_avg_balance = round(average_balance, 2)

#call new variable
rounded_avg_balance
# Out:
# 2771.95

# %%
#a shorter way of doing the above would be doing all the steps at once
#round to two decimal places and get the average at the same time
round_avg= round(total_balance/total_num_users, 2)

#call this new variable
round_avg
# Out:
# 2771.95

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3f. User with the lowest balance

# %%
#create new variable like we did above with profile_ids
#this will create a list of balances
list_of_balances = [profile['balance'] for profile in profiles]

#call new variable
list_of_balances
# Out:
# [2097.02,
#  3654.02,
#  1536.02,
#  3919.64,
#  3681.39,
#  1694.42,
#  1214.1,
#  2930.31,
#  1944.15,
#  2839.22,
#  2467.31,
#  3304.99,
#  3844.42,
#  3594.99,
#  2940.24,
#  3062.41,
#  3067.82,
#  2646.76,
#  2227.79]

# %%
#from here we can do a simple min
min(list_of_balances)
# Out:
# 1214.1

# %%
#put it all together
#if the balance is equal to the min of balances on the list we created
#print out the name (from profile) and the balance (from profile)- using f string literal
for profile in profiles:
    if profile['balance'] == min(list_of_balances):       
        print(f'User {profile["name"]} has the lowest balance of {profile["balance"]}')
        
#spacing and indentation DOES matter
# Out:
# User Avery Flynn has the lowest balance of 1214.1

# %%
# OPTION #2

#using the list_of_balances, .index() will return the position of the smallest balance
list_of_balances.index(min(list_of_balances))
# Out:
# 6

# %%
#save the index as a variable to reference
min_bal_index = list_of_balances.index(min(list_of_balances))

#call the name from the indexed JSON
profiles[min_bal_index]['name']
# Out:
# 'Avery Flynn'

# %%
#OPTION #3

#create an empty list
balance_ls = []

#iterate through each profile
for profile in profiles:
    #remove specal characters from the balance
    user_balance = profile['balance']
    #print each user's balance
    print(user_balance)
    #add the next user's balance to the list
    balance_ls.append(user_balance)
# Out:
# 2097.02
# 3654.02
# 1536.02
# 3919.64
# 3681.39
# 1694.42
# 1214.1
# 2930.31
# 1944.15
# 2839.22
# 2467.31
# 3304.99
# 3844.42
# 3594.99
# 2940.24
# 3062.41
# 3067.82
# 2646.76
# 2227.79

# %%
min(balance_ls)
# Out:
# 1214.1

# %%
#now, let's find which user that balance belongs to

#iterate through each profile
for profile in profiles:
    #remove special characters and give minumum balance
    if profile['balance'] == min(balance_ls):
        #print the user name and balance
        print(f'User: {profile["name"]}- has the least amount of cash: ${profile["balance"]}')
# Out:
# User: Avery Flynn- has the least amount of cash: $1214.1

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3g. User with the highest balance

# %%
#use variable created above but with max
max(list_of_balances)
# Out:
# 3919.64

# %%
##put it all together
#if the balance is equal to the max of balances on the list we created
#print out the name (from profile) and the balance (from profile)- using f string literal
for profile in profiles:
    if profile['balance'] == max(list_of_balances):       
        print(f'User {profile["name"]} has the lowest balance of ${profile["balance"]}')
        
#spacing and indentation DOES matter
# Out:
# User Fay Hammond has the lowest balance of $3919.64

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3h. Most common favorite fruit

# %%
#create variable fruits using .append to view favoriteFruit from the profile 
#This is one way to do it
fruits = []
for profile in profiles:
    fruits.append(profile["favoriteFruit"])
    
fruits
# Out:
# ['strawberry',
#  'apple',
#  'apple',
#  'banana',
#  'apple',
#  'apple',
#  'banana',
#  'strawberry',
#  'strawberry',
#  'banana',
#  'strawberry',
#  'strawberry',
#  'apple',
#  'strawberry',
#  'strawberry',
#  'banana',
#  'strawberry',
#  'apple',
#  'strawberry']

# %%
#lets see what the different types of fruit are
set(fruits)
# Out:
# {'apple', 'banana', 'strawberry'}

# %%
#This is returning the **STRING** with the most # of characters
max(fruits)
# Out:
# 'strawberry'

# %%
#This is returning the Fruit with the highest list count
max(fruits, key=fruits.count)
# Out:
# 'strawberry'

# %%
#get counts for how many apples we have to double check
fruits.count('apple'), fruits.count('banana'), fruits.count('strawberry')
# Out:
# (6, 4, 9)

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3i. Least most common favorite fruit

# %%
#This is returning the Fruit with the lowest list count
min(fruits, key=fruits.count)
# Out:
# 'banana'

# %% [markdown]
# <hr style="border:1px solid black">

# %% [markdown]
# ## 3j. Total number of unread messages for all users

# %%
#create a variable named messages that takes the greeting from profile and splits it on the space
message = profile['greeting'].split(' ')

# %%
#call the new variable so we can see what it looks like
message
# Out:
# ['Hello,', 'Ewing', 'Larson!', 'You', 'have', '16', 'unread', 'messages.']

# %%
#here we are going to create a for loop with the new message variable we just created
#we are saying that IF the word is a DIGIT
#print "this is a number" and the number from word
for word in message:
    if word.isdigit():
        print('this is a number: ', word)
# Out:
# this is a number:  16

# %%
#we are starting with 0
#using what we just learned above
#splitting the greeting on spaces
#if there is a digit in the greeting, we turn that into an integer
#return the total number of unread messages for all users

sum_messages = 0

for profile in profiles:
    message = profile['greeting'].split(' ')
    for word in message:
        if word.isdigit():
            sum_messages = sum_messages + int(word)
            
sum_messages
# Out:
# 210

# %%
#ANOTHER WAY

#create an empty list
greeting_list = []

#iterate through each profile
for profile in profiles:
    #show/print greeting only
    print(profile['greeting'])
    #add the next greeting to the list
    greeting_list.append(profile['greeting'])
# Out:
# Hello, Hebert Estes! You have 4 unread messages.
# Hello, Allison Wynn! You have 19 unread messages.
# Hello, Jacobs Floyd! You have 5 unread messages.
# Hello, Fay Hammond! You have 10 unread messages.
# Hello, Chasity Marsh! You have 9 unread messages.
# Hello, Camacho Cortez! You have 19 unread messages.
# Hello, Avery Flynn! You have 13 unread messages.
# Hello, Michael Cash! You have 17 unread messages.
# Hello, Madeleine Bray! You have 2 unread messages.
# Hello, Corine French! You have 18 unread messages.
# Hello, Trudy Cummings! You have 2 unread messages.
# Hello, Peggy Mayer! You have 13 unread messages.
# Hello, Chan Hurley! You have 7 unread messages.
# Hello, Diaz Pena! You have 13 unread messages.
# Hello, Heath Castaneda! You have 12 unread messages.
# Hello, Greer Blankenship! You have 7 unread messages.
# Hello, Coffey Hayes! You have 19 unread messages.
# Hello, Leanne Hurst! You have 5 unread messages.
# Hello, Ewing Larson! You have 16 unread messages.

# %%
#in order to isolate just the number
##we have to split on white space

message = profile['greeting'].split(' ')
message
# Out:
# ['Hello,', 'Ewing', 'Larson!', 'You', 'have', '16', 'unread', 'messages.']

# %%
for word in message:
    if word.isdigit():
        print('The number of unread messages is: ', word)
# Out:
# The number of unread messages is:  16

# %%
#another way to accomplish this
sum_messages = 0

for profile in profiles:
    message = profile['greeting'].split(' ')
    for word in message:
        if word.isdigit():
            sum_messages = sum_messages + int(word)
            
sum_messages
# Out:
# 210

# %% [markdown]
# <hr style="border:2px solid gray">
# <hr style="border:2px solid gray">

# %% [markdown]
# ### Visual Representation of a `for` Loop Converted to List Comprehension
# ![image.png](attachment:383dea4f-51ee-4112-891b-74ddb805c337.png)
